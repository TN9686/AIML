# %%
dic = { "name" : "john", "age":30,"city":"New York"}
print(dic["name"])
# Out:
# john

# %%
#keys are case senstive
word={}
word["hello"]= "world"
word["Hello"]= "welcome"
print(word)
# Out:
# {'hello': 'world', 'Hello': 'welcome'}

# %%
p={"raj":1,"ram":2,"shyam":3}
print(p)
p["sona"]=4
print(p)
# Out:
# {'raj': 1, 'ram': 2, 'shyam': 3}
# {'raj': 1, 'ram': 2, 'shyam': 3, 'sona': 4}

# %%
#two strings , so it shows error, because set are mutable and mutable are not hasable
p={{"raj"}:1, "ram":2, "shyam":3}
print(p)
p["raj"]=4
print(p)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 #two strings , so it shows error, because set are mutable and mutable are not hasable
# ----> 2 p={{"raj"}:1, "ram":2, "shyam":3}
#       3 print(p)
#       4 p["raj"]=4
#
# TypeError: unhashable type: 'set'

# %%
#Write a program to input ‘n’ employee numbers and names and store them in a dictionary. Display dictionaries employee’s names(key) and numbers(values) together.
n = int(input("Enter number of employees: "))
employees = {}
for i in range(n):
    name = input("Enter name: ")
    num = input("Enter number: ")
    employees[name] = num
print(employees)
# Out:
# Enter number of employees:  4
