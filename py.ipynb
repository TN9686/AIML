# %%
a = 10
b = 20
result = a + b
print("The sum is:", result)
# Out:
# The sum is: 30

# %%
#these are unordered bcz they follow hash table. when duplicates enter values override so dict does not contain duplicate values
student = {
    "name": "Pallavi",
    "age": 20,
    "course": "Engineering"
}
print(student)
# Out:
# {'name': 'Pallavi', 'age': 20, 'course': 'Engineering'}

# %%
word={}
word["hello"]="world"
word["hello"]="welcome"
print(word)
# Out:
# {'hello': 'welcome'}

# %%
#unhashable type:"set" bcz trying to insert dict inside dict
#dict follows hash table
p={{1}:1,"a":2,"b":3}
print(p)
p["pav"]=4
print(p)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 #unhashable type:"set" bcz trying to insert dict inside dict
# ----> 2 p={{1}:1,"a":2,"b":3}
#       3 print(p)
#       4 p["pav"]=4
#
# TypeError: unhashable type: 'set'

# %%
class Stack:
    def __init__(self):
        self.stack=[]
    def push(self,item):
        self.stack+=[item]
    def pop(self):
        if not self.isEmpty():
            top_element=self.stack[len(self.stack)-1]
            self.stack=

# %%
class Dog:
    species="Canine"
    color="black"
    name="sona"
    def __init__(self,name,age):
        self.name=name
        self.age=age
dog1=Dog("Buddy",3)
print(dog1,name)
print(dog1,species)
print(dog1,color)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 9
#       7         self.age=age
#       8 dog1=Dog("Buddy",3)
# ----> 9 print(dog1,name)
#      10 print(dog1,species)
#      11 print(dog1,color)
#
# NameError: name 'name' is not defined

# %%
n = 5
ans = 1
while (n>0):
    ans*=n
    print(ans)
    n-=1
# Out:
# 5
# 20
# 60
# 120
# 120
